# %% [markdown]
# # Artifical Neural Networks

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.metrics import accuracy_score, classification_report,confusion_matrix

# %%
# Load the Iris dataset
iris = load_iris()
X = iris.data  # Features
y = iris.target.reshape(-1, 1)  # Target

# One-hot encode the target labels
encoder = OneHotEncoder(sparse_output=False)
y_encoded = encoder.fit_transform(y)

# Split dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Standardize
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Define the ANN model
model = keras.Sequential([
    keras.layers.Dense(10, activation='relu', input_shape=(4,)),  # Input Layer (4 features)
    keras.layers.Dense(8, activation='relu'),                      # Hidden Layer
    keras.layers.Dense(3, activation='softmax')                    # Output Layer (3 classes)
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Summary of the model
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                      │ (None, 10)                  │              50 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 8)                   │              88 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 3)                   │              27 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 165 (660.00 B)
#  Trainable params: 165 (660.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=5, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.2475 - loss: 1.1244 - val_accuracy: 0.3333 - val_loss: 1.0810
# Epoch 2/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2954 - loss: 1.0797 - val_accuracy: 0.3333 - val_loss: 1.0474
# Epoch 3/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2751 - loss: 1.0561 - val_accuracy: 0.3333 - val_loss: 1.0099
# Epoch 4/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3379 - loss: 1.0039 - val_accuracy: 0.3333 - val_loss: 0.9430
# Epoch 5/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3027 - loss: 0.9824 - val_accuracy: 0.6667 - val_loss: 0.8702
# Epoch 6/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6537 - loss: 0.9039 - val_accuracy: 0.7000 - val_loss: 0.7952
# Epoch 7/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7038 - loss: 0.8283 - val_accuracy: 0.7000 - val_loss: 0.7274
# Epoch 8/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6847 - loss: 0.7563 - val_accuracy: 0.7333 - val_loss: 0.6543
# Epoch 9/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7030 - loss: 0.7140 - val_accuracy: 0.8000 - val_loss: 0.5796
# Epoch 10/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7338 - loss: 0.6077 - val_accuracy: 0.8333 - val_loss: 0.5072
# Epoch 11/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8218 - loss: 0.5113 - val_accuracy: 0.8667 - val_loss: 0.4334
# Epoch 12/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8648 - loss: 0.4982 - val_accuracy: 0.9000 - val_loss: 0.3861
# Epoch 13/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8931 - loss: 0.4056 - val_accuracy: 0.9000 - val_loss: 0.3463
# Epoch 14/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8831 - loss: 0.4126 - val_accuracy: 0.9333 - val_loss: 0.3126
# Epoch 15/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9182 - loss: 0.3210 - val_accuracy: 0.9333 - val_loss: 0.2840
# Epoch 16/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8526 - loss: 0.3727 - val_accuracy: 0.9333 - val_loss: 0.2619
# Epoch 17/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9117 - loss: 0.2931 - val_accuracy: 0.9333 - val_loss: 0.2437
# Epoch 18/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8876 - loss: 0.2931 - val_accuracy: 0.9667 - val_loss: 0.2254
# Epoch 19/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9423 - loss: 0.2531 - val_accuracy: 0.9667 - val_loss: 0.2100
# Epoch 20/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9603 - loss: 0.2179 - val_accuracy: 0.9667 - val_loss: 0.1957
# Epoch 21/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9122 - loss: 0.2538 - val_accuracy: 0.9667 - val_loss: 0.1839
# Epoch 22/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9332 - loss: 0.2514 - val_accuracy: 0.9667 - val_loss: 0.1759
# Epoch 23/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9504 - loss: 0.2158 - val_accuracy: 0.9667 - val_loss: 0.1671
# Epoch 24/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9619 - loss: 0.1713 - val_accuracy: 0.9667 - val_loss: 0.1593
# Epoch 25/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9729 - loss: 0.1775 - val_accuracy: 1.0000 - val_loss: 0.1510
# Epoch 26/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9464 - loss: 0.1992 - val_accuracy: 1.0000 - val_loss: 0.1453
# Epoch 27/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9694 - loss: 0.1601 - val_accuracy: 1.0000 - val_loss: 0.1401
# Epoch 28/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9602 - loss: 0.1842 - val_accuracy: 1.0000 - val_loss: 0.1334
# Epoch 29/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9649 - loss: 0.1582 - val_accuracy: 1.0000 - val_loss: 0.1281
# Epoch 30/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9611 - loss: 0.1574 - val_accuracy: 1.0000 - val_loss: 0.1231
# Epoch 31/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9670 - loss: 0.1582 - val_accuracy: 1.0000 - val_loss: 0.1196
# Epoch 32/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9109 - loss: 0.1863 - val_accuracy: 1.0000 - val_loss: 0.1162
# Epoch 33/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9525 - loss: 0.1353 - val_accuracy: 1.0000 - val_loss: 0.1131
# Epoch 34/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9460 - loss: 0.1735 - val_accuracy: 1.0000 - val_loss: 0.1076
# Epoch 35/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9520 - loss: 0.1268 - val_accuracy: 1.0000 - val_loss: 0.1079
# Epoch 36/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9551 - loss: 0.1649 - val_accuracy: 1.0000 - val_loss: 0.1030
# Epoch 37/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9373 - loss: 0.1374 - val_accuracy: 1.0000 - val_loss: 0.1014
# Epoch 38/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9497 - loss: 0.1358 - val_accuracy: 1.0000 - val_loss: 0.0967
# Epoch 39/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9426 - loss: 0.1367 - val_accuracy: 1.0000 - val_loss: 0.0972
# Epoch 40/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9772 - loss: 0.1173 - val_accuracy: 1.0000 - val_loss: 0.0931
# Epoch 41/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9735 - loss: 0.1226 - val_accuracy: 1.0000 - val_loss: 0.0932
# Epoch 42/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9788 - loss: 0.0995 - val_accuracy: 1.0000 - val_loss: 0.0903
# Epoch 43/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9447 - loss: 0.1146 - val_accuracy: 1.0000 - val_loss: 0.0878
# Epoch 44/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9701 - loss: 0.0969 - val_accuracy: 1.0000 - val_loss: 0.0868
# Epoch 45/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9730 - loss: 0.1009 - val_accuracy: 1.0000 - val_loss: 0.0827
# Epoch 46/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9513 - loss: 0.1203 - val_accuracy: 1.0000 - val_loss: 0.0808
# Epoch 47/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9404 - loss: 0.1432 - val_accuracy: 1.0000 - val_loss: 0.0848
# Epoch 48/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9777 - loss: 0.0889 - val_accuracy: 1.0000 - val_loss: 0.0770
# Epoch 49/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9399 - loss: 0.0962 - val_accuracy: 1.0000 - val_loss: 0.0784
# Epoch 50/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9783 - loss: 0.0885 - val_accuracy: 1.0000 - val_loss: 0.0743

# %%
# Evaluate on test data
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy:.2f}")

# Predict on test set
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_test_classes = np.argmax(y_test, axis=1)

# Print classification report
print("\nClassification Report:\n", classification_report(y_test_classes, y_pred_classes))

# Print confusion matrix
print("\nConfusion Matrix:\n",confusion_matrix(y_test_classes,y_pred_classes))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 1.0000 - loss: 0.0743
# Test Accuracy: 1.00
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30
#
#
# Confusion Matrix:
#  [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]

# %%
# Plot Accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Test Accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Model Accuracy")
plt.legend()
plt.show()

# Plot Loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Model Loss")
plt.legend()
plt.show()
